# %%
# %pip install hurst
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from hurst import compute_Hc
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('EMBR3.SA.csv')['Close']

H, c, data = compute_Hc(data, kind='price', simplified=True)

f, ax = plt.subplots()
ax.plot(data[0], c*data[0]**H, color="deepskyblue")
ax.scatter(data[0], data[1], color="purple")
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Time interval')
ax.set_ylabel('R/S ratio')
ax.grid(True)
plt.savefig('Hurst_EMBRAER.png')
plt.show()

print("H={:.4f}, c={:.4f}".format(H,c))
# Out:
# H=0.7095, c=0.8198

# %%
data = pd.read_csv('PETR3.SA.csv')['Close']

H, c, data = compute_Hc(data, kind='price', simplified=True)

f, ax = plt.subplots()
ax.plot(data[0], c*data[0]**H, color="deepskyblue")
ax.scatter(data[0], data[1], color="purple")
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Time interval')
ax.set_ylabel('R/S ratio')
ax.grid(True)
plt.savefig('Hurst_PETRA.png')
plt.show()

print("H={:.4f}, c={:.4f}".format(H,c))
# Out:
# H=0.6706, c=0.7888

# %%
data = pd.read_csv('VALE3.SA.csv')['Close']

H, c, data = compute_Hc(data, kind='price', simplified=True)

f, ax = plt.subplots()
ax.plot(data[0], c*data[0]**H, color="deepskyblue")
ax.scatter(data[0], data[1], color="purple")
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Time interval')
ax.set_ylabel('R/S ratio')
ax.grid(True)
plt.savefig('Hurst_VALE.png')
plt.show()

print("H={:.4f}, c={:.4f}".format(H,c))
# Out:
# H=0.7201, c=0.7360
